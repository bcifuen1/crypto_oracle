# %%
import os 
import json 
import time 
import datetime
import requests
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
start_date = datetime.date(2020, 6, 16)
end_date = datetime.date(2020, 9, 16)
delta = datetime.timedelta(days=1)
articles=[]
while start_date <= end_date:
    # print(start_date)
    gnews_url = f"https://gnews.io/api/v4/search?q=bitcoin&in=cryptocurrency$from={start_date}T00:01:36Z&to={start_date}T23:59:36Z&lang=en&token=109989618e479cd03b57c69c7cf5aac3"
    response = requests.get(gnews_url)
    data = response.json()
    articles.append(data)
    start_date += delta
    time.sleep(3)

# %%
articles
# Out:
# [{'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
#     'content': 'Text size\nA technical change in Bitcoin has brought new attention to the cryptocurrency, but the price bump that came ahead of the adjustment doesn’t seem to have held.\nThe so-called halving, which took place on Monday, reduced the number of Bitcoins... [2039 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-dips-after-halving-but-the-publicity-is-helping-51589293172',
#     'image': 'https://images.barrons.com/im-186035/social',
#     'publishedAt': '2020-05-12T14:19:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': 'Bitcoin Rallies Above $10,000. Don’t Think of It as a Hedge.',
#     'description': 'The cryptocurrency has more than doubled in price since March, but it seems to be moving in line with riskier assets such as stocks.',
#     'content': 'Text size\nBitcoin rose above $10,000 late on Thursday and traded near that level on Friday, at about $9,930, as enthusiasm has grown for the digital money. The price has more than doubled from less than $4,000 in March.\nAs always with Bitcoin, there ... [2635 chars]',
#     'url': 'https://www.barrons.com/articles/bitcoin-rallies-above-10-000-dont-think-of-it-as-a-hedge-51588952763',
#     'image': 'https://images.barrons.com/im-185054/social',
#     'publishedAt': '2020-05-08T15:46:00Z',
#     'source': {'name': "Barron's", 'url': 'https://www.barrons.com'}},
#    {'title': '6 reasons bitcoin is trading at its highest level since 2017 — and 1 warning',
#     'description': 'Bitcoin, the digital currency that is arguably one of the most polarizing assets in financial markets, is approaching heights not seen since a frenzied rush...',
#     'content': 'Bitcoin is baaack!\nThe popular digital currency, which is arguably one of the most polarizing in financial markets, is approaching heights not seen since the frenzied rush into cryptocurrencies three years ago.\nBitcoin’s price BTCUSD, -1.85% on Wedne... [7565 chars]',
#     'url': 'https://www.marketwatch.com/story/6-reasons-bitcoin-is-trading-at-its-highest-level-since-2017-and-1-warning-11605733477',
#     'image': 'https://images.mktw.net/im-261771/social',
#     'publishedAt': '2017-01-27T05:00:00Z',
#     'source': {'name': 'MarketWatch', 'url': 'https://www.marketwatch.com'}},
#    {'title': 'Bitcoin tops $22,000 and the rally has further to go',
#     'description': 'By Joanna Ossinger Bitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency. The digital coin jumped as much as 4.6% to about $22,173 on Thursday, before paring some of the advance. Bitcoin and the wider Bloomberg Galaxy Crypto Index have both more than tripled this',
#     'content': 'By Joanna Ossinger\nBitcoin has surged about 20% this week, breaching $22,000 for the first time and stirring predictions that more gains lie ahead for the world’s largest cryptocurrency.\nThe digital coin jumped as much as 4.6% to about $22,173 on Thu... [2173 chars]',
#     'url': 'https://www.deccanherald.com/business/business-news/bitcoin-tops-22000-and-the-rally-has-further-to-go-928287.html',
#     'image': 'https://www.deccanherald.com/sites/dh/files/articleimages/2020/12/17/404010-01-022-928287-1608187454.jpg',
#     'publishedAt': '2000-12-16T18:30:00Z',
#     'source': {'name': 'Deccan Herald',
#      'url': 'https://www.deccanherald.com'}}]},
#  {'totalArticles': 4,
#   'articles': [{'title': 'Bitcoin Dips After Halving, but the Publicity Is Helping',
#     'description': 'A technical change in Bitcoin has brought new attention to the cryptocurrency, but the pre-event price bump doesn’t seem to have held.',
# ...
#     'url': 'https://seekingalpha.com/news/3613818-microstrategy-makes-bitcoin-primary-treasury-reserve',
#     'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#     'publishedAt': '2020-09-14T19:06:40Z',
#     'source': {'name': 'Seeking Alpha', 'url': 'https://seekingalpha.com'}},
#    {'title': 'Forget gold and Bitcoin. I’d buy crashing stocks today to make a million',
#     'description': 'Buying crashing stocks could lead to higher returns in the long run than other assets such as gold and Bitcoin, in my opinion.',
#     'content': 'Motley Fool Australia » Value Investing » Forget gold and Bitcoin. I’d buy crashing stocks today to make a million\nBuying crashing stocks to make a million may not be an appealing idea to many investors at the present time. The uncertain global econo... [2994 chars]',
#     'url': 'https://www.fool.com.au/2020/09/13/forget-gold-and-bitcoin-id-buy-crashing-stocks-today-to-make-a-million/',
#     'image': 'https://www.fool.com.au/wp-content/uploads/2020/07/asx-iron-ore-shares-doomed.jpg',
#     'publishedAt': '2020-09-13T00:30:10Z',
#     'source': {'name': 'Motley Fool Australia',
#      'url': 'https://www.fool.com.au'}},
#    {'title': 'Researcher kept a major Bitcoin bug secret for two years to prevent attacks',
#     'description': 'The INVDoS bug would have allowed attackers to crash Bitcoin nodes and other similar blockchains.',
#     'content': 'In 2018, a security researcher discovered a major vulnerability in Bitcoin Core, the software that powers the Bitcoin blockchain, but after reporting the issue and having it patched, the researcher opted to keep details private in order to avoid hack... [2735 chars]',
#     'url': 'https://www.zdnet.com/article/researcher-kept-a-major-bitcoin-bug-secret-for-two-years-to-prevent-attacks/',
#     'image': 'https://zdnet2.cbsistatic.com/hub/i/r/2020/09/12/5d7eabd7-f35e-4bd6-8267-a3473504905d/thumbnail/770x578/6eee13296178a5b6d953a6998713b825/invdos-logo.png',
#     'publishedAt': '2020-09-12T14:25:00Z',
#     'source': {'name': 'ZDNet', 'url': 'https://www.zdnet.com'}},
#    {'title': "Forget Bitcoin: Here's How to Build Wealth Without Excessive Volatility",
#     'description': 'Bitcoin has been ridiculously volatile in the face of this crisis. Investors should seek safety in low-beta stocks like Hydro One Ltd. (TSX:H) instead.',
#     'content': 'The Motley Fool Canada » Investing » Forget Bitcoin: Here’s How to Build Wealth Without Excessive Volatility\nBitcoin, or Millennial Gold, as some like to call it, isn’t doing a very good job of acting like a gold alternative. Gold is a lowly correlat... [3026 chars]',
#     'url': 'https://www.fool.ca/2020/09/12/forget-bitcoin-heres-how-to-build-wealth-without-excessive-volatility/',
#     'image': 'https://yw553ftvhw1iqegz29fycoyw-wpengine.netdna-ssl.com/wp-content/uploads/2019/10/Businessman-holding-tablet-and-showing-a-growing-virtual-hologram-of-statistics-graph-and-chart-with-arrow-up-on-dark-background.-Stock-market.-Business-growth-planning-and-strategy-concept.jpg',
#     'publishedAt': '2020-09-12T12:20:09Z',
#     'source': {'name': 'The Motley Fool Canada',
#      'url': 'https://www.fool.ca'}},
#    {'title': 'Chart Of The Day: Bitcoin Testing Critical Zone; Decisive Breakdown Ahead?',
#     'description': "Market Analysis by Fawad Razaqzada covering: Nasdaq 100, XAU/USD, S&P 500, SPDR S&P 500. Read Fawad Razaqzada's Market Analysis on Investing.com",
#     'content': 'This article was written exclusively for Investing.com\nhas stabilized after last week’s sharp sell-off, but is there going to be more short-term pain before we see long-term gains, or is the selling already done?\nAfter last week’s sizeable drop, Bitc... [4134 chars]',
#     'url': 'https://www.investing.com/analysis/chart-of-the-day-bitcoin-testing-critical-zone-as-investors-weigh-macro-factors-200537189',
#     'image': 'https://i-invdn-com.akamaized.net/redesign/images/seo/v2/investingcom_analysis_og.jpg',
#     'publishedAt': '2020-09-11T04:00:00Z',
#     'source': {'name': 'Investing.com', 'url': 'https://www.investing.com'}},
#    {'title': 'ECB considering move to digital euro says Lagarde',
#     'description': 'Central banks around the world are considering the creation of digital currencies to compete with the likes of Bitcoin and other crypto currencies',
#     'content': 'The European Central Bank (ECB) is exploring the pros and cons of introducing a digital euro to complement cash and will publish its findings in the coming weeks before launching a consultation, ECB President Christine Lagarde said today.\nMajor centr... [1229 chars]',
#     'url': 'https://www.breakingnews.ie/business/ecb-considering-move-to-digital-euro-says-lagarde-1016563.html',
#     'image': 'https://www.breakingnews.ie/remote/media.central.ie/media/images/c/ChristineLagardeIMF220116a_large.jpg?width=600&s=bn-1016563',
#     'publishedAt': '2020-09-10T20:06:00Z',
#     'source': {'name': 'BreakingNews.ie',
#      'url': 'https://www.breakingnews.ie'}},
#    {'title': "Bitcoin Rallies as CNBC's Jim Cramer Plans to Invest",
#     'description': "Bitcoin's price rose Thursday after Anthony Pompliano announced CNBC's Jim Cramer has been convinced to invest.",
#     'content': 'Bitcoin rose Thursday after it was announced Jim Cramer would be investing in BTC.\nBTC/USD bulls cheered as Anthony “Pomp” Pompliano made the announcement.\nThe CNBC “Mad Money” host is the latest high-profile investor to jump on the cryptocurrency ba... [2421 chars]',
#     'url': 'https://www.ccn.com/bitcoin-rallies-cnbcsl-jim-cramer/',
#     'image': 'https://ccncdn-f07d.kxcdn.com/wp-content/uploads/2020/09/NTB_syWm7dNJQGM-e1599763552974.jpg',
#     'publishedAt': '2020-09-10T18:28:25Z',
#     'source': {'name': 'CCN.com', 'url': 'https://www.ccn.com'}},
#    {'title': 'Crypto Traders Cut Out the Middleman, Simply Rob Victim',
#     'description': 'Two alleged crypto traders in Singapore apparently came up with a fool-proof plan: rather than convert a customer’s 365,000 Singapore dollars to bitcoin, they would simply rob the victim when he came in to do the trade.',
#     'content': 'Photo : Sean Gallup / Staff ( Getty Images )\nTwo alleged crypto traders in Singapore apparently came up with a fool-proof plan: r ather than convert a customer’s 365,000 Singapore dollars to bitcoin, they would simply rob the victim when he came in t... [1794 chars]',
#     'url': 'https://gizmodo.com/crypto-traders-cut-out-the-middleman-simply-rob-victim-1845011301',
#     'image': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/li0fkkejdmaugm8v1fkw.jpg',
#     'publishedAt': '2020-09-10T14:28:00Z',
#     'source': {'name': 'Gizmodo', 'url': 'https://gizmodo.com'}}]},
#  {'totalArticles': 32,
#   'articles': [{'title': 'Victim of bitcoin scam out nearly $4K',
#     'description': 'Victim told her SIN was used to rent a car, was instructed to send $3,800 in bitcoin or she would go to jail',
#     'content': 'Victim told her SIN was used to rent a car, was instructed to send $3,800 in bitcoin or she would go to jail\nNEWS RELEASE\nGUELPH POLICE SERVICE\n*******************************\nOn Sept. 15, 2020 at 10 a.m., an adult female victim received a phone call... [1068 chars]',
#     'url': 'https://www.guelphtoday.com/police/victim-of-bitcoin-scam-out-nearly-4k-2716978',
#     'image': 'https://www.vmcdn.ca/f/files/shared/miscellaneous-stock-images/bitcoin-adobestock_61457857.jpeg;w=1200;h=800;mode=crop',
#     'publishedAt': '2020-09-16T14:23:53Z',
#     'source': {'name': 'GuelphToday', 'url': 'https://www.guelphtoday.com'}},
#    {'title': 'ICE Bakkt Bitcoin futures contracts rises 36% from previous record',
#     'description': 'Intercontinental Exchange (NYSE:ICE) reported record trading volume for its Bakkt Bitcoin (USD) Physically Delivered Monthly Futures contracts. The Futures',
#     'content': 'Intercontinental Exchange (NYSE:ICE) reported record trading volume for its Bakkt Bitcoin (USD) Physically Delivered Monthly Futures contracts.\nThe Futures traded 15,955 contracts on September 15, 2020, 36% higher from previous record of 11,706 on Ju... [12 chars]',
#     'url': 'https://seekingalpha.com/news/3614535-ice-bakkt-bitcoin-futures-contracts-rises-36-from-previous-record',
#     'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#     'publishedAt': '2020-09-16T12:38:28Z',
#     'source': {'name': 'Seeking Alpha', 'url': 'https://seekingalpha.com'}},
#    {'title': 'MicroStrategy Bitcoin buys now total $425M',
#     'description': 'The company yesterday completed the acquisition of another 16,796 Bitcoins (BTC-USD) for a total purchase price of $175M. Combined with previous purchases,',
#     'content': "The company yesterday completed the acquisition of another 16,796 Bitcoins (BTC-USD) for a total purchase price of $175M. Combined with previous purchases, the company has now spent $425M for 38,250 Bitcoins - that's 11,111 each vs. current price jus... [292 chars]",
#     'url': 'https://seekingalpha.com/news/3614123-microstrategy-bitcoin-buys-now-total-425m',
#     'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#     'publishedAt': '2020-09-15T13:26:05Z',
#     'source': {'name': 'Seeking Alpha', 'url': 'https://seekingalpha.com'}},
#    {'title': 'Besides bitcoin, Indians buy tether, ethereum cryptocurrencies',
#     'description': '"Bitcoin is the flag bearer of cryptocurrencies. Also, it\'s more liquid and the less volatile compared to other currencies. Hence, most people come to the exchange to buy bitcoins."',
#     'content': 'New technology is upending everything in finance, from saving to trading to making payments.\nIndians have a clear favourite when it comes to cryptocurrencies. The world’s largest virtual currency by market capitalisation—bitcoin—is the most traded cr... [1679 chars]',
#     'url': 'https://qz.com/india/1901633/besides-bitcoin-indians-buy-tether-ethereum-cryptocurrencies/',
#     'image': 'https://cms.qz.com/wp-content/uploads/2020/09/2020-04-17T171755Z_1338037002_RC2H6G9123HN_RTRMADP_3_HEALTH-CORONAVIRUS-BITCOIN-e1599733300420.jpg?quality=75&strip=all&w=1400',
#     'publishedAt': '2020-09-15T05:13:04Z',
#     'source': {'name': 'Quartz India', 'url': 'https://qz.com'}},
#    {'title': 'MicroStrategy makes bitcoin its primary treasury reserve',
#     'description': 'Last month, MicroStrategy (MSTR +1.2%)\xa0shares popped after the company said it would spend half of its $500M cash hoard to purchase bitcoin. In a new filin',
#     'content': 'Last month, MicroStrategy (MSTR +1.2% ) shares popped after the company said it would spend half of its $500M cash hoard to purchase bitcoin.\nIn a new filing, MicroStrategy reveals the board has approved a new policy that splits the treasury reserve ... [586 chars]',
#     'url': 'https://seekingalpha.com/news/3613818-microstrategy-makes-bitcoin-primary-treasury-reserve',
#     'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#     'publishedAt': '2020-09-14T19:06:40Z',
#     'source': {'name': 'Seeking Alpha', 'url': 'https://seekingalpha.com'}},
#    {'title': 'Forget gold and Bitcoin. I’d buy crashing stocks today to make a million',
#     'description': 'Buying crashing stocks could lead to higher returns in the long run than other assets such as gold and Bitcoin, in my opinion.',
#     'content': 'Motley Fool Australia » Value Investing » Forget gold and Bitcoin. I’d buy crashing stocks today to make a million\nBuying crashing stocks to make a million may not be an appealing idea to many investors at the present time. The uncertain global econo... [2994 chars]',
#     'url': 'https://www.fool.com.au/2020/09/13/forget-gold-and-bitcoin-id-buy-crashing-stocks-today-to-make-a-million/',
#     'image': 'https://www.fool.com.au/wp-content/uploads/2020/07/asx-iron-ore-shares-doomed.jpg',
#     'publishedAt': '2020-09-13T00:30:10Z',
#     'source': {'name': 'Motley Fool Australia',
#      'url': 'https://www.fool.com.au'}},
#    {'title': 'Researcher kept a major Bitcoin bug secret for two years to prevent attacks',
#     'description': 'The INVDoS bug would have allowed attackers to crash Bitcoin nodes and other similar blockchains.',
#     'content': 'In 2018, a security researcher discovered a major vulnerability in Bitcoin Core, the software that powers the Bitcoin blockchain, but after reporting the issue and having it patched, the researcher opted to keep details private in order to avoid hack... [2735 chars]',
#     'url': 'https://www.zdnet.com/article/researcher-kept-a-major-bitcoin-bug-secret-for-two-years-to-prevent-attacks/',
#     'image': 'https://zdnet2.cbsistatic.com/hub/i/r/2020/09/12/5d7eabd7-f35e-4bd6-8267-a3473504905d/thumbnail/770x578/6eee13296178a5b6d953a6998713b825/invdos-logo.png',
#     'publishedAt': '2020-09-12T14:25:00Z',
#     'source': {'name': 'ZDNet', 'url': 'https://www.zdnet.com'}},
#    {'title': "Forget Bitcoin: Here's How to Build Wealth Without Excessive Volatility",
#     'description': 'Bitcoin has been ridiculously volatile in the face of this crisis. Investors should seek safety in low-beta stocks like Hydro One Ltd. (TSX:H) instead.',
#     'content': 'The Motley Fool Canada » Investing » Forget Bitcoin: Here’s How to Build Wealth Without Excessive Volatility\nBitcoin, or Millennial Gold, as some like to call it, isn’t doing a very good job of acting like a gold alternative. Gold is a lowly correlat... [3026 chars]',
#     'url': 'https://www.fool.ca/2020/09/12/forget-bitcoin-heres-how-to-build-wealth-without-excessive-volatility/',
#     'image': 'https://yw553ftvhw1iqegz29fycoyw-wpengine.netdna-ssl.com/wp-content/uploads/2019/10/Businessman-holding-tablet-and-showing-a-growing-virtual-hologram-of-statistics-graph-and-chart-with-arrow-up-on-dark-background.-Stock-market.-Business-growth-planning-and-strategy-concept.jpg',
#     'publishedAt': '2020-09-12T12:20:09Z',
#     'source': {'name': 'The Motley Fool Canada',
#      'url': 'https://www.fool.ca'}},
#    {'title': 'Chart Of The Day: Bitcoin Testing Critical Zone; Decisive Breakdown Ahead?',
#     'description': "Market Analysis by Fawad Razaqzada covering: Nasdaq 100, XAU/USD, S&P 500, SPDR S&P 500. Read Fawad Razaqzada's Market Analysis on Investing.com",
#     'content': 'This article was written exclusively for Investing.com\nhas stabilized after last week’s sharp sell-off, but is there going to be more short-term pain before we see long-term gains, or is the selling already done?\nAfter last week’s sizeable drop, Bitc... [4134 chars]',
#     'url': 'https://www.investing.com/analysis/chart-of-the-day-bitcoin-testing-critical-zone-as-investors-weigh-macro-factors-200537189',
#     'image': 'https://i-invdn-com.akamaized.net/redesign/images/seo/v2/investingcom_analysis_og.jpg',
#     'publishedAt': '2020-09-11T04:00:00Z',
#     'source': {'name': 'Investing.com', 'url': 'https://www.investing.com'}},
#    {'title': 'ECB considering move to digital euro says Lagarde',
#     'description': 'Central banks around the world are considering the creation of digital currencies to compete with the likes of Bitcoin and other crypto currencies',
#     'content': 'The European Central Bank (ECB) is exploring the pros and cons of introducing a digital euro to complement cash and will publish its findings in the coming weeks before launching a consultation, ECB President Christine Lagarde said today.\nMajor centr... [1229 chars]',
#     'url': 'https://www.breakingnews.ie/business/ecb-considering-move-to-digital-euro-says-lagarde-1016563.html',
#     'image': 'https://www.breakingnews.ie/remote/media.central.ie/media/images/c/ChristineLagardeIMF220116a_large.jpg?width=600&s=bn-1016563',
#     'publishedAt': '2020-09-10T20:06:00Z',
#     'source': {'name': 'BreakingNews.ie',
#      'url': 'https://www.breakingnews.ie'}}]}]

# %%
articles_df = pd.json_normalize(articles, record_path=["articles"], meta="totalArticles")
articles_df['title&description']= articles_df['title']+ " " +articles_df['description']
articles_df = articles_df[['publishedAt', 'title&description', 'totalArticles']]
articles_df.rename(columns={'publishedAt':'date'}, inplace=True)
articles_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7d9cf9e6c71e> in <module>
# ----> 1 articles_df = pd.json_normalize(articles, record_path=["articles"], meta="totalArticles")
#       2 articles_df['title&description']= articles_df['title']+ " " +articles_df['description']
#       3 articles_df = articles_df[['publishedAt', 'title&description', 'totalArticles']]
#       4 articles_df.rename(columns={'publishedAt':'date'}, inplace=True)
#       5 articles_df.head()
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
# clean dataframe and add a column that is composed of "title" and "description". Also group dataframe by "publish date"
articles_df['date']=pd.to_datetime(articles_df['date'], infer_datetime_format=True).dt.date
bitcoin_articles= articles_df.groupby(by=["date",'totalArticles']).sum()
bitcoin_articles.head()

# %%
# Import the libraries for sentiment scoring using Vader
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# %%
# Define two lists to store vader sentiment scoring
y_vader_pred = []
y_vader_prob = []

# %%
# Score sentiment of test set using Vader
for text in bitcoin_articles["title&description"]:
    y_vader_prob.append(analyzer.polarity_scores(text)["pos"])
    sentiment_score = analyzer.polarity_scores(text)["compound"]
    if sentiment_score >= 0.1:
        y_vader_pred.append(1)
    else:
        y_vader_pred.append(0)

# %%
# add sentiment score to bitcoin_articles dataframe
bitcoin_articles["Sentiment Score"]=y_vader_pred
bitcoin_articles.head()

# %%
# import ccxt SDK and get bitcoin historical prices from kraken
import ccxt
kraken_public_key = os.getenv("KRAKEN_PUBLIC_KEY")
kraken_secret_key = os.getenv("KRAKEN_SECRET_KEY")
kraken = ccxt.kraken({"apiKey": kraken_public_key, "secret": kraken_secret_key})

historical_prices = kraken.fetch_ohlcv("BTC/USD","1d")

# %%
historical_prices_df = pd.DataFrame(historical_prices, columns=["date", "open", "high", "low", "close", "volume"])
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["date"], unit="ms"
)
historical_prices_df.set_index("date",inplace=True)
historical_prices_df.head()

# %%
# Drop NAs and calculate daily percent return
historical_prices_df['daily_return'] = historical_prices_df['close'].dropna().pct_change()
historical_prices_df['volume change'] = historical_prices_df['volume'].pct_change().shift(-1)
historical_prices_df['spread'] = (historical_prices_df['high'] - historical_prices_df['low'])/historical_prices_df['open']
historical_prices_df.head
()

# %%
combined_df = bitcoin_articles.join(historical_prices_df)
combined_df['articles'] = combined_df['articles'].shift(-1)
combined_df.head()

# %%
# analyzing tone of bitcoin articles with ibm_watson tone analyzer SDK
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

ibm_key = os.getenv("ibm_key")
authenticator = IAMAuthenticator(ibm_key)
tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.us-east.tone-analyzer.watson.cloud.ibm.com')
tone_analyzer.set_disable_ssl_verification(True)

# %%
tone_analyzed = []
for text in combined_df["title&description"]:
    tone_analysis = tone_analyzer.tone(
    {'text': text},
    content_type='application/json').get_result()
    tone_analyzed.append(tone_analysis)

# %%
# working on figuring out how to convert tone_analyzed into sparse matrix that will be merged with combined_df so we evaluate extra features.
tone=[]
for text in tone_analyzed:
    dic={}
    tone.append(dic)
    for emotions in text["document_tone"]["tones"]:
        dic.update({emotions['tone_id']:emotions['score']})
data = pd.DataFrame(tone)
data.fillna(0,inplace=True)
data.head()

# %%
combined_df.reset_index(inplace=True)
all_df = combined_df.join(data)
all_df.set_index("date",inplace=True)

# %%
all_df.head()

# %%
#all_df.to_csv('ben_sentiment.csv')
